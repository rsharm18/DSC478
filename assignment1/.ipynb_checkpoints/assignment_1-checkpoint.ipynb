# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot  as plt
# %matplotlib inline

# %%
dataFileName='http://facweb.cs.depaul.edu/mobasher/classes/csc478/Data/bank_data.csv'
df = pd.read_csv(dataFileName,index_col=0)
df_not_normalized=df.copy()
df.shape
# Out:
# (600, 11)

# %%
df.columns
# Out:
# Index(['age', 'income', 'children', 'gender', 'region', 'married', 'car',
#        'savings_acct', 'current_acct', 'mortgage', 'pep'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 600 entries, ID12101 to ID12700
# Data columns (total 11 columns):
# age             600 non-null int64
# income          600 non-null float64
# children        600 non-null int64
# gender          600 non-null object
# region          600 non-null object
# married         600 non-null object
# car             600 non-null object
# savings_acct    600 non-null object
# current_acct    600 non-null object
# mortgage        600 non-null object
# pep             600 non-null object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 56.2+ KB

# %%
df.dtypes
# Out:
# age               int64
# income          float64
# children          int64
# gender           object
# region           object
# married          object
# car              object
# savings_acct     object
# current_acct     object
# mortgage         object
# pep              object
# dtype: object

# %% [markdown]
# #### 1. Explore the general characteristics of the data as a whole:
#        examine the means, standard deviations, and other statistics associated with the numerical attributes;
#        also show the distributions of values associated with categorical attributes (for categorical attributes use Matplotlib library and/or plotting capabilities of Pandas to generate bar charts showing the distribution of categories for each attribute).

# %%
df.describe()
# Out:
#               age        income    children
# count  600.000000    600.000000  600.000000
# mean    42.395000  27524.031217    1.011667
# std     14.424947  12899.468246    1.056752
# min     18.000000   5014.210000    0.000000
# 25%     30.000000  17264.500000    0.000000
# 50%     42.000000  24925.300000    1.000000
# 75%     55.250000  36172.675000    2.000000
# max     67.000000  63130.100000    3.000000

# %% [markdown]
# ### Suppose that the hypothetical bank is particularly interested in customers who buy the PEP (Personal Equity Plan) product. Compare and contrast the subsets of customers who buy and don't buy the PEP. Compute summaries (as in part 1) of the selected data with respect to all other attributes (you do not need to plot distributions). Can you observe any significant differences between these segments of customers? Discuss your observations.

# %%
df.pep.head(3)
# Out:
# id
# ID12101    YES
# ID12102     NO
# ID12103     NO
# Name: pep, dtype: object

# %%
#customer who buy pep
cutomers_buy_pep=df[df.pep=='YES']
cutomers_buy_pep.describe()
# Out:
#               age        income    children
# count  274.000000    274.000000  274.000000
# mean    45.127737  30644.919453    0.945255
# std     14.327991  13609.613043    0.860571
# min     18.000000   7756.360000    0.000000
# 25%     34.000000  19639.475000    0.000000
# 50%     45.000000  28080.050000    1.000000
# 75%     58.000000  38458.350000    1.000000
# max     67.000000  63130.100000    3.000000

# %%
#customer who dont buy pep
cutomers_dont_buy_pep=df[df.pep=='NO']
cutomers_dont_buy_pep.describe()
# Out:
#               age        income    children
# count  326.000000    326.000000  326.000000
# mean    40.098160  24900.953374    1.067485
# std     14.123506  11661.123422    1.195524
# min     18.000000   5014.210000    0.000000
# 25%     27.000000  15366.475000    0.000000
# 50%     40.000000  23105.000000    0.000000
# 75%     51.000000  31210.900000    2.000000
# max     67.000000  61554.600000    3.000000

# %%
## observation
#  based on the above, people who tend to buy PEP are a bit older , have  high incomes and no children
# whereas the customers are relatively younger with lower income and with a children tend to not buy PEP.

# %% [markdown]
# #### 3. Use z-score normalization to standardize the values of the income attribute. [Do not change the original income attribute or add the normalized income to the table.]

# %%
## Use z-score normalization to standardize the values of the income attribute.
zscore = lambda x : ((x - x.mean())/x.std()) if(x.dtypes==np.float64 or x.dtypes==np.int64) else x
df_income=df.income

df_norm_income = (df_income - df_income.mean())/df_income.std()
df_norm_income.head(5)
# Out:
# id
# ID12101   -0.773523
# ID12102    0.198541
# ID12103   -0.848766
# ID12104   -0.554180
# ID12105    1.787071
# Name: income, dtype: float64

# %% [markdown]
# #### 4. Discretize the age attribute into 3 categories (corresponding to "young", "mid-age", and "old"). [Do not change the original age attribute or add the discretized age to the table.

# %%
age_discreet = pd.qcut(df.age,[0,.4,.7,1], labels=['young', 'mid-age','old'])
age_discreet.head(5)
# Out:
# id
# ID12101    mid-age
# ID12102    mid-age
# ID12103    mid-age
# ID12104      young
# ID12105        old
# Name: age, dtype: category
# Categories (3, object): [young < mid-age < old]

# %% [markdown]
# #### 5. Use Min-Max Normalization to transform the values of all numeric attributes  (income, age, children) in the original table onto the range 0.0-1.0.

# %%
min_max=lambda x: ((x - x.min())/(x.max() - x.min())) if(x.dtypes==np.float64 or x.dtypes==np.int64) else x
df=df.apply(min_max);
df.describe()
# Out:
#               age      income    children
# count  600.000000  600.000000  600.000000
# mean     0.497857    0.387326    0.337222
# std      0.294387    0.221961    0.352251
# min      0.000000    0.000000    0.000000
# 25%      0.244898    0.210791    0.000000
# 50%      0.489796    0.342610    0.333333
# 75%      0.760204    0.536144    0.666667
# max      1.000000    1.000000    1.000000

# %% [markdown]
# #### 6. Convert the table (after normalization in part 5) into the standard spreadsheet format. Note that this requires converting each categorical attribute into multiple binary ("dummy") attributes (one for each values of the categorical attribute) and assigning binary values corresponding to the presence or not presence of the attribute value in the original record). The numeric attributes should remain unchanged. Save this new table into a file called bank_numeric.csv and submit it along with your assignment.

# %%
df_ssf=pd.get_dummies(df)
df_ssf.to_csv("bank_numeric.csv", float_format="%1.2f")
df_ssf.head(4)
# Out:
#               age    income  children  gender_FEMALE  gender_MALE  \
# id
# ID12101  0.612245  0.215634  0.333333              1            0
# ID12102  0.448980  0.431395  1.000000              0            1
# ID12103  0.673469  0.198933  0.000000              1            0
# ID12104  0.102041  0.264320  1.000000              1            0
#
#          region_INNER_CITY  region_RURAL  region_SUBURBAN  region_TOWN  \
# id
# ID12101                  1             0                0            0
# ID12102                  0             0                0            1
# ID12103                  1             0                0            0
# ID12104                  0             0                0            1
#
#          married_NO   ...     car_NO  car_YES  savings_acct_NO  \
# id                    ...
# ID12101           1   ...          1        0                1
# ID12102           0   ...          0        1                1
# ID12103           0   ...          0        1                0
# ID12104           0   ...          1        0                1
#
#          savings_acct_YES  current_acct_NO  current_acct_YES  mortgage_NO  \
# id
# ID12101                 0                1                 0            1
# ID12102                 0                0                 1            0
# ID12103                 1                0                 1            1
# ID12104                 0                0                 1            1
#
#          mortgage_YES  pep_NO  pep_YES
# id
# ID12101             0       0        1
# ID12102             1       1        0
# ID12103             0       1        0
# ID12104             0       1        0
#
# [4 rows x 21 columns]

# %% [markdown]
# #### 7. Using the numeric data set with the dummy variables (of the previous part), perform basic correlation analysis among the attributes. Discuss your results by indicating any significant positive or negative correlations among pairs of attributes. You need to construct a complete Correlation Matrix. Be sure to first remove the Customer ID column before creating the correlation matrix. [Hint: you can create the correlation matrix by using the corr() function in Pandas or corrcoef function in NumPy].

# current_acct_YES           1.000000     0.036704     -0.036704 -0.025141
# mortgage_NO                0.036704     1.000000     -1.000000 -0.024182
# mortgage_YES              -0.036704    -1.000000      1.000000  0.024182
# pep_NO                    -0.025141    -0.024182      0.024182  1.000000
# pep_YES                    0.025141     0.024182     -0.024182 -1.000000
#
#                     pep_YES
# age                0.173825
# income             0.221991
# children          -0.057663
# gender_FEMALE     -0.046843
# gender_MALE        0.046843
# region_INNER_CITY  0.001054
# region_RURAL       0.019714
# region_SUBURBAN    0.062508
# region_TOWN       -0.059115
# married_NO         0.189578
# married_YES       -0.189578
# car_NO            -0.018917
# car_YES            0.018917
# savings_acct_NO    0.072779
# savings_acct_YES  -0.072779
# current_acct_NO   -0.025141
# current_acct_YES   0.025141
# mortgage_NO        0.024182
# mortgage_YES      -0.024182
# pep_NO            -1.000000
# pep_YES            1.000000
#
# [21 rows x 21 columns]

# %% [markdown]
# ##### observation
#   from the data, it is clear that income creases with age. thus income is positively correlated with age
#   female seem have higher income compared to Mens, hence gender_FEMALE is postively correlated with age and income
#   male seem have lower income compared to Female, hence gender_MALE is negatively correlated with age and income
#
#   customers with car seem to have higher income hence income and car are positivel correlated'
#   current_acct_NO is negeatively corelated with income but positively correlated to age
#   current_acct_YES is negeatively corelated with age but positively correlated to income
#
#   pep is positevely correlated with age and number

# %% [markdown]
# #### 8. Create a scatter plot of the (non-normalized) Income attribute relative to Age. Be sure that your plot contains appropriate labels for the axes. Do these variables seem correlated?

# %%
fig, ax = plt.subplots()
df_not_normalized.plot(x='income', y='age',kind='scatter',s=df.age*0.5, alpha=0.8,c="income", cmap=plt.get_cmap("jet"), colorbar=True, figsize=(10,7),ax=ax)

# %% [markdown]
# #### observation
# from the scatter plot looks like the income increase with age. Hence, age and income are positively correlated.

# %% [markdown]
# #### 9. Create histograms for (non-normalized) Income (using 9 bins) and Age (using 15 bins).

# %%
fig = plt.figure(figsize=(10,4))
ax1 = fig.add_subplot(121)
ax1.set_xlabel('Income')
ax1.set_title("Income Distribution")
df_not_normalized.income.plot(kind='hist',bins=9, grid = True)

ax1 = fig.add_subplot(122)
ax1.set_xlabel('Age')
ax1.set_title("Age Distribution")
df_not_normalized.age.plot(kind='hist',bins=15, grid =True)

# %% [markdown]
# #### 10. Perform a cross-tabulation of the region attribute with the pep attribute. This requires the aggregation of the occurrences of each pep value (yes or no) separately for each value of the region attribute. Show the results as a 4 by 2 (region x pep) table with entries representing the counts. [Hint: you can either use Numpy or use aggregations functions in Pandas such as groupby() and  cross-tab().] Then, either using Matplotlib directly or the plot() function in Pandas create a bar chart graph to visualize of the relationships between these sets of variables.

# %%
gg = pd.crosstab(df_not_normalized.region,df_not_normalized.pep)
gg
# Out:
# pep          NO  YES
# region
# INNER_CITY  146  123
# RURAL        50   46
# SUBURBAN     28   34
# TOWN        102   71

# %%
plt.show(gg.plot(kind='bar'))

# %% [markdown]
# #### 11. Now consider a modified version of the bank data that contains missing values (bank_data_missing_vals.csv). (a) Using Pandas determine all the attributes with missing values and the number of missing values for each such attribute. (b) Show all the instances in the data that contain a missing value. (c) Fill the missing values for all numeric attributes using the mean value for the attribute. (d) After filling in the missing numeric values, drop all rows where a categorical attribute contains a missing value. (e) Show that the final resulting table does not contain missing values.

# %%
empy_dataFileName='http://facweb.cs.depaul.edu/mobasher/classes/csc478/Assignments/bank_data_missing_vals.csv'
df_missing_val = pd.read_csv(empy_dataFileName,index_col=0,na_values=['?'])
df_missing_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 600 entries, ID12101 to ID12700
# Data columns (total 11 columns):
# age             590 non-null float64
# income          587 non-null float64
# children        600 non-null int64
# gender          590 non-null object
# region          591 non-null object
# married         600 non-null object
# car             600 non-null object
# savings_acct    600 non-null object
# current_acct    600 non-null object
# mortgage        600 non-null object
# pep             600 non-null object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 56.2+ KB

# %% [markdown]
# #### 11.a Using Pandas determine all the attributes with missing values and the number of missing values for each such attribute
#
# from the above info, we can infer the below
#
# | Attribute 	| # of rows 	| # of non null rows 	| # of Missing values 	|
# |-----------	|-----------	|--------------------	|---------------------	|
# | age       	| 600       	| 590                	| 10                  	|
# | income    	| 600       	| 587                	| 13                  	|
# | gender    	| 600       	| 590                	| 10                  	|
# | region    	| 600       	| 591                	| 9                   	|

# %% [markdown]
# #### 11.b  Show all the instances in the data that contain a missing value.

# %%
df_missing_val[df_missing_val.isnull().any(axis=1)] ##column
# Out:
#           age    income  children  gender      region married  car  \
# id
# ID12104  23.0       NaN         3  FEMALE        TOWN     YES   NO
# ID12107  22.0   8877.07         0    MALE         NaN      NO   NO
# ID12109  37.0       NaN         2  FEMALE    SUBURBAN     YES  YES
# ID12135  43.0       NaN         0    MALE    SUBURBAN      NO   NO
# ID12142  47.0  26952.60         0     NaN  INNER_CITY     YES  YES
# ID12162  65.0  36589.00         1  FEMALE         NaN      NO  YES
# ID12178  61.0  49456.70         1     NaN  INNER_CITY     YES  YES
# ID12182  30.0       NaN         3    MALE  INNER_CITY      NO   NO
# ID12189  30.0  15848.70         0    MALE         NaN     YES  YES
# ID12202   NaN  11604.40         2  FEMALE  INNER_CITY     YES  YES
# ID12242  47.0  22791.40         0     NaN  INNER_CITY     YES   NO
# ID12248  20.0  18860.30         2  FEMALE         NaN      NO   NO
# ID12283  65.0       NaN         0  FEMALE  INNER_CITY      NO  YES
# ID12285  38.0       NaN         0  FEMALE  INNER_CITY      NO  YES
# ID12293  64.0  49024.90         3     NaN       RURAL     YES   NO
# ID12351  65.0       NaN         0    MALE  INNER_CITY      NO   NO
# ID12380  40.0  36972.40         1    MALE         NaN     YES   NO
# ID12381  32.0  22327.80         1     NaN  INNER_CITY     YES   NO
# ID12411   NaN  30658.70         0    MALE        TOWN     YES   NO
# ID12454  48.0       NaN         1    MALE        TOWN      NO  YES
# ID12461   NaN  51620.80         2  FEMALE        TOWN      NO  YES
# ID12462  56.0  19918.90         3    MALE         NaN     YES   NO
# ID12484  40.0  34836.80         1     NaN        TOWN     YES  YES
# ID12487  49.0       NaN         0    MALE  INNER_CITY      NO   NO
# ID12527   NaN       NaN         3  FEMALE        TOWN     YES   NO
# ID12544   NaN  33302.80         0    MALE        TOWN      NO  YES
# ID12557  32.0  13267.60         0  FEMALE         NaN     YES  YES
# ID12562  64.0  24554.10         0     NaN    SUBURBAN     YES  YES
# ID12566  57.0       NaN         2  FEMALE        TOWN     YES  YES
# ID12568  34.0  12810.20         3  FEMALE         NaN      NO   NO
# ID12579   NaN  23337.20         2    MALE        TOWN     YES   NO
# ID12610   NaN  11215.30         2  FEMALE       RURAL     YES  YES
# ID12639   NaN  38784.00         0  FEMALE  INNER_CITY     YES   NO
# ID12649   NaN  20736.20         1    MALE       RURAL     YES  YES
# ID12650  58.0  52662.50         1     NaN        TOWN     YES  YES
# ID12670  49.0  17944.20         1    MALE         NaN      NO  YES
# ID12685  33.0       NaN         1     NaN        TOWN     YES   NO
# ID12692   NaN  31473.90         2  FEMALE  INNER_CITY      NO   NO
# ID12693  48.0  20268.00         0     NaN        TOWN     YES   NO
# ID12697  30.0       NaN         0  FEMALE  INNER_CITY     YES  YES
#
#         savings_acct current_acct mortgage  pep
# id
# ID12104           NO          YES       NO   NO
# ID12107           NO          YES       NO  YES
# ID12109           NO           NO       NO   NO
# ID12135          YES          YES       NO  YES
# ID12142           NO          YES       NO   NO
# ID12162           NO          YES       NO  YES
# ID12178          YES          YES      YES  YES
# ID12182           NO          YES       NO   NO
# ID12189          YES           NO      YES   NO
# ID12202          YES          YES       NO   NO
# ID12242           NO          YES       NO   NO
# ID12248          YES          YES       NO   NO
# ID12283          YES          YES      YES   NO
# ID12285          YES           NO      YES   NO
# ID12293          YES          YES       NO  YES
# ID12351          YES          YES      YES   NO
# ID12380           NO          YES      YES  YES
# ID12381           NO           NO       NO  YES
# ID12411          YES          YES       NO   NO
# ID12454          YES          YES       NO  YES
# ID12461          YES          YES       NO  YES
# ID12462          YES          YES      YES   NO
# ID12484          YES          YES       NO  YES
# ID12487           NO          YES       NO   NO
# ID12527          YES           NO       NO   NO
# ID12544           NO          YES      YES  YES
# ID12557          YES          YES      YES   NO
# ID12562          YES           NO      YES   NO
# ID12566          YES          YES      YES   NO
# ID12568          YES          YES       NO  YES
# ID12579          YES          YES      YES   NO
# ID12610          YES          YES       NO  YES
# ID12639          YES          YES       NO   NO
# ID12649          YES          YES       NO  YES
# ID12650          YES          YES      YES  YES
# ID12670          YES          YES      YES  YES
# ID12685          YES          YES      YES  YES
# ID12692          YES          YES      YES  YES
# ID12693          YES          YES       NO   NO
# ID12697          YES          YES       NO   NO

# %%
## 11.c Fill the missing values for all numeric attributes using the mean value for the attribute
df_missing_val.fillna(df_missing_val.mean(),axis=0,inplace=True)
df_missing_val
# Out:
#                age        income  children  gender      region married  car  \
# id
# ID12101  48.000000  17546.000000         1  FEMALE  INNER_CITY      NO   NO
# ID12102  40.000000  30085.100000         3    MALE        TOWN     YES  YES
# ID12103  51.000000  16575.400000         0  FEMALE  INNER_CITY     YES  YES
# ID12104  23.000000  27475.594685         3  FEMALE        TOWN     YES   NO
# ID12105  57.000000  50576.300000         0  FEMALE       RURAL     YES   NO
# ID12106  57.000000  37869.600000         2  FEMALE        TOWN     YES   NO
# ID12107  22.000000   8877.070000         0    MALE         NaN      NO   NO
# ID12108  58.000000  24946.600000         0    MALE        TOWN     YES  YES
# ID12109  37.000000  27475.594685         2  FEMALE    SUBURBAN     YES  YES
# ID12110  54.000000  24212.100000         2    MALE        TOWN     YES  YES
# ID12111  66.000000  59803.900000         0  FEMALE        TOWN     YES   NO
# ID12112  52.000000  26658.800000         0  FEMALE  INNER_CITY      NO  YES
# ID12696  61.000000  47025.000000         2  FEMALE  INNER_CITY      NO  YES
# ID12697  30.000000  27475.594685         0  FEMALE  INNER_CITY     YES  YES
# ID12698  31.000000  15976.300000         0  FEMALE        TOWN     YES  YES
# ID12699  29.000000  14711.800000         0    MALE  INNER_CITY     YES   NO
# ID12700  38.000000  26671.600000         0    MALE        TOWN      NO  YES
#
#         savings_acct current_acct mortgage  pep
# id
# ID12101           NO           NO       NO  YES
# ID12102           NO          YES      YES   NO
# ID12103          YES          YES       NO   NO
# ID12104           NO          YES       NO   NO
# ID12105          YES           NO       NO   NO
# ID12106          YES          YES       NO  YES
# ID12107           NO          YES       NO  YES
# ID12108          YES          YES       NO   NO
# ID12109           NO           NO       NO   NO
# ID12110          YES          YES       NO   NO
# ID12111          YES          YES       NO   NO
# ID12112          YES          YES      YES   NO
# ID12113          YES          YES      YES  YES
# ID12114          YES          YES      YES  YES
# ID12115          YES          YES      YES   NO
# ID12116          YES          YES      YES   NO
# ID12117           NO           NO      YES   NO
# ID12118          YES           NO      YES   NO
# ID12119          YES           NO       NO  YES
# ID12120          YES          YES       NO   NO
# ID12121          YES           NO       NO  YES
# ID12122          YES          YES       NO   NO
# ID12123          YES          YES       NO   NO
# ID12124          YES          YES      YES   NO
# ID12125          YES          YES       NO   NO
# ID12126          YES          YES      YES   NO
# ID12127          YES          YES      YES   NO
# ID12128           NO          YES       NO  YES
# ID12129           NO          YES      YES   NO
# ID12130           NO          YES       NO  YES
# ...              ...          ...      ...  ...
# ID12671           NO          YES       NO   NO
# ID12672           NO           NO       NO   NO
# ID12673          YES          YES       NO  YES
# ID12674          YES          YES       NO   NO
# ID12675          YES          YES       NO   NO
# ID12676          YES          YES      YES   NO
# ID12677          YES          YES       NO  YES
# ID12678          YES           NO       NO  YES
# ID12679          YES          YES      YES   NO
# ID12680           NO           NO       NO   NO
# ID12681          YES           NO      YES  YES
# ID12682           NO          YES      YES   NO
# ID12683          YES           NO       NO   NO
# ID12684          YES          YES       NO   NO
# ID12685          YES          YES      YES  YES
# ID12686          YES          YES       NO   NO
# ID12687           NO          YES       NO  YES
# ID12688          YES           NO       NO  YES
# ID12689          YES          YES       NO   NO
# ID12690          YES          YES       NO   NO
# ID12691           NO           NO       NO   NO
# ID12692          YES          YES      YES  YES
# ID12693          YES          YES       NO   NO
# ID12694          YES          YES       NO  YES
# ID12695          YES          YES      YES   NO
# ID12696          YES          YES      YES   NO
# ID12697          YES          YES       NO   NO
# ID12698          YES           NO       NO  YES
# ID12699          YES           NO      YES   NO
# ID12700           NO          YES      YES  YES
#
# [600 rows x 11 columns]

# %%
## 11.d After filling in the missing numeric values, drop all rows where a categorical attribute contains a missing value.
df_missing_val.dropna(axis=0,inplace=True)
df_missing_val
# Out:
#                age        income  children  gender      region married  car  \
# id
# ID12101  48.000000  17546.000000         1  FEMALE  INNER_CITY      NO   NO
# ID12102  40.000000  30085.100000         3    MALE        TOWN     YES  YES
# ID12103  51.000000  16575.400000         0  FEMALE  INNER_CITY     YES  YES
# ID12104  23.000000  27475.594685         3  FEMALE        TOWN     YES   NO
# ID12105  57.000000  50576.300000         0  FEMALE       RURAL     YES   NO
# ID12688  43.000000  31273.800000         1  FEMALE        TOWN      NO  YES
# ID12689  58.000000  49673.600000         0    MALE       RURAL     YES   NO
# ID12690  29.000000  12623.400000         1    MALE    SUBURBAN     YES  YES
# ID12691  25.000000  23818.600000         0    MALE  INNER_CITY     YES   NO
# ID12692  42.376271  31473.900000         2  FEMALE  INNER_CITY      NO   NO
# ID12694  65.000000  51417.000000         2    MALE    SUBURBAN     YES   NO
# ID12695  59.000000  30971.800000         3  FEMALE       RURAL     YES  YES
# ID12696  61.000000  47025.000000         2  FEMALE  INNER_CITY      NO  YES
# ID12697  30.000000  27475.594685         0  FEMALE  INNER_CITY     YES  YES
# ID12698  31.000000  15976.300000         0  FEMALE        TOWN     YES  YES
# ID12699  29.000000  14711.800000         0    MALE  INNER_CITY     YES   NO
# ID12700  38.000000  26671.600000         0    MALE        TOWN      NO  YES
#
#         savings_acct current_acct mortgage  pep
# id
# ID12101           NO           NO       NO  YES
# ID12102           NO          YES      YES   NO
# ID12103          YES          YES       NO   NO
# ID12104           NO          YES       NO   NO
# ID12105          YES           NO       NO   NO
# ID12106          YES          YES       NO  YES
# ID12108          YES          YES       NO   NO
# ID12109           NO           NO       NO   NO
# ID12110          YES          YES       NO   NO
# ID12111          YES          YES       NO   NO
# ID12112          YES          YES      YES   NO
# ID12113          YES          YES      YES  YES
# ID12114          YES          YES      YES  YES
# ID12115          YES          YES      YES   NO
# ID12116          YES          YES      YES   NO
# ID12117           NO           NO      YES   NO
# ID12118          YES           NO      YES   NO
# ID12119          YES           NO       NO  YES
# ID12120          YES          YES       NO   NO
# ID12121          YES           NO       NO  YES
# ID12122          YES          YES       NO   NO
# ID12123          YES          YES       NO   NO
# ID12124          YES          YES      YES   NO
# ID12125          YES          YES       NO   NO
# ID12126          YES          YES      YES   NO
# ID12127          YES          YES      YES   NO
# ID12128           NO          YES       NO  YES
# ID12129           NO          YES      YES   NO
# ID12130           NO          YES       NO  YES
# ID12131          YES          YES       NO   NO
# ...              ...          ...      ...  ...
# ID12668          YES          YES       NO   NO
# ID12669          YES          YES       NO   NO
# ID12671           NO          YES       NO   NO
# ID12672           NO           NO       NO   NO
# ID12673          YES          YES       NO  YES
# ID12674          YES          YES       NO   NO
# ID12675          YES          YES       NO   NO
# ID12676          YES          YES      YES   NO
# ID12677          YES          YES       NO  YES
# ID12678          YES           NO       NO  YES
# ID12679          YES          YES      YES   NO
# ID12680           NO           NO       NO   NO
# ID12681          YES           NO      YES  YES
# ID12682           NO          YES      YES   NO
# ID12683          YES           NO       NO   NO
# ID12684          YES          YES       NO   NO
# ID12686          YES          YES       NO   NO
# ID12687           NO          YES       NO  YES
# ID12688          YES           NO       NO  YES
# ID12689          YES          YES       NO   NO
# ID12690          YES          YES       NO   NO
# ID12691           NO           NO       NO   NO
# ID12692          YES          YES      YES  YES
# ID12694          YES          YES       NO  YES
# ID12695          YES          YES      YES   NO
# ID12696          YES          YES      YES   NO
# ID12697          YES          YES       NO   NO
# ID12698          YES           NO       NO  YES
# ID12699          YES           NO      YES   NO
# ID12700           NO          YES      YES  YES
#
# [581 rows x 11 columns]
